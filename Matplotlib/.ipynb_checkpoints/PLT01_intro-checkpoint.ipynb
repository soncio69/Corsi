# %% [markdown]
# # Basic
# Utilizzando direttamente il metodo plt.plot() si ottiene di default un lineplot che può essere customizzato (vedi sotto)

# %%
from matplotlib import pyplot as plt

ages_x = [ 22, 23, 24, 25, 26, 28, 33, 34, 38, 44]

py_dev_y = [ 27455, 29330, 37234, 39564, 46456, 49765, 59534, 60886, 69456, 77544]
plt.plot(ages_x, py_dev_y, label='Python', color='b', marker='.', linewidth=3)

js_dev_y = [ 21455, 22330, 32234, 34564, 40456, 42765, 51534, 52886, 60456, 64544]
plt.plot(ages_x, js_dev_y, label='javascript', color='#444444', marker='o', linewidth=3)

dev_y = [ 23455, 24433, 34234, 36564, 43456, 46765, 54534, 57886, 65456, 67544]
plt.plot(ages_x, dev_y, linestyle='--', color='k', label='Complessivo')

plt.title('Salario medio per età')
plt.xlabel('Età')
plt.ylabel('Salario')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('grafico.png')
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
from matplotlib import pyplot as plt

plt.style.use('fivethirtyeight')
ages_x = [ 22, 23, 24, 25, 26, 28, 33, 34, 38, 44]

py_dev_y = [ 27455, 29330, 37234, 39564, 46456, 49765, 59534, 60886, 69456, 77544]
plt.plot(ages_x, py_dev_y, label='Python')

js_dev_y = [ 21455, 22330, 32234, 34564, 40456, 42765, 51534, 52886, 60456, 64544]
plt.plot(ages_x, js_dev_y, label='javascript')

dev_y = [ 23455, 24433, 34234, 36564, 43456, 46765, 54534, 57886, 65456, 67544]
plt.plot(ages_x, dev_y,label='Complessivo')

plt.title('Salario medio per età')
plt.xlabel('Età')
plt.ylabel('Salario')

plt.legend()
plt.tight_layout()
plt.show()

# %%
from matplotlib import pyplot as plt

plt.xkcd()
ages_x = [ 22, 23, 24, 25, 26, 28, 33, 34, 38, 44]

py_dev_y = [ 27455, 29330, 37234, 39564, 46456, 49765, 59534, 60886, 69456, 77544]
plt.plot(ages_x, py_dev_y, label='Python')

js_dev_y = [ 21455, 22330, 32234, 34564, 40456, 42765, 51534, 52886, 60456, 64544]
plt.plot(ages_x, js_dev_y, label='javascript')

dev_y = [ 23455, 24433, 34234, 36564, 43456, 46765, 54534, 57886, 65456, 67544]
plt.plot(ages_x, dev_y,label='Complessivo')

plt.title('Salario medio per età')
plt.xlabel('Età')
plt.ylabel('Salario')

plt.legend()
plt.tight_layout()
plt.show()
