# %%
import pandas as pd

df =  pd.read_csv('data\survey_results_public.csv', index_col='Respondent')
df_schema =  pd.read_csv('data\survey_results_schema.csv', index_col='Column')

pd.set_option('display.max_columns', 85 )
pd.set_option('display.max_rows', 85 )

df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.sort_values(by='Country',inplace=True)
df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 39258               I am a developer by profession      Yes
# 85825       I am a student who is learning to code      Yes
# 85715               I am a developer by profession       No
# 50767               I am a developer by profession       No
# 2782                                           NaN      Yes
#
#                         OpenSourcer  \
# Respondent
# 39258       Less than once per year
# 85825       Less than once per year
# 85715       Less than once per year
# 50767       Less than once per year
# 2782        Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 39258       OSS is, on average, of LOWER quality than prop...
# 85825       OSS is, on average, of LOWER quality than prop...
# 85715       The quality of OSS and closed source software ...
# 50767                                                     NaN
# ...

# %%
# Visualizzo solo le 2 colonne che mi interessano
df[['Country','ConvertedComp']]
# Out:
#                 Country  ConvertedComp
# Respondent
# 39258       Afghanistan        19152.0
# 85825       Afghanistan            NaN
# 85715       Afghanistan            NaN
# 50767       Afghanistan            NaN
# 2782        Afghanistan            NaN
# ...                 ...            ...
# 88062               NaN            NaN
# 88076               NaN            NaN
# 88601               NaN            NaN
# 88802               NaN            NaN
# 88816               NaN            NaN
#
# [88883 rows x 2 columns]

# %%
#  Per ordinare x Country crescente e salario decrescente
df.sort_values(by=['Country','ConvertedComp'], ascending=[True,False],inplace=True)
# Visualizzo solo le 2 colonne che mi interessano
df[['Country','ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 63129       Afghanistan      1000000.0
# 50499       Afghanistan       153216.0
# 39258       Afghanistan        19152.0
# 58450       Afghanistan        17556.0
# 7085        Afghanistan        14364.0
# 22450       Afghanistan         7980.0
# 48436       Afghanistan         4464.0
# 10746       Afghanistan         3996.0
# 8149        Afghanistan         1596.0
# 29736       Afghanistan         1116.0
# 28638       Afghanistan            0.0
# 722         Afghanistan            0.0
# 85825       Afghanistan            NaN
# 85715       Afghanistan            NaN
# 50767       Afghanistan            NaN
# 2782        Afghanistan            NaN
# 63019       Afghanistan            NaN
# 6417        Afghanistan            NaN
# 40000       Afghanistan            NaN
# 88731       Afghanistan            NaN
# 62525       Afghanistan            NaN
# 49702       Afghanistan            NaN
# 33178       Afghanistan            NaN
# ...

# %%
# Ci sono dei modi  alternativi per ottenere valori sulla bese di un ordinamento
# Ad esempio con il metodo nlargest (sia per una Series che per un DataFrame)
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
# il  metodo nlargest può essere applicato anche  a DataFrame
df.nlargest(5, 'ConvertedComp')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      Yes
# 87896                          I am a developer by profession      Yes
# 22013                          I am a developer by profession      Yes
# 28243                          I am a developer by profession      Yes
# 72732       I am not primarily a developer, but I write co...       No
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# 87896                                 Less than once per year
# 22013                                                   Never
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
# Esiste anche il metodo nsmalest()
